# %% [markdown]
# ### 4.3 MF의 최적 파라미터 찾기

# %% [markdown]
# iterations가 일정 수를 넘어가면 train set에 지나치게 맞춰져서 과적합이생긴다. 잠재요인의 수인 K가 지나치게 커지는 경우도 과적합이 발생한다.

# %%
import numpy as np
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('u.data', names=r_cols,  sep='\t',encoding='latin-1')
ratings = ratings[['user_id', 'movie_id', 'rating']].astype(int)            # timestamp 제거

# %% [markdown]
# - train test 분리

# %%
from sklearn.utils import shuffle
TRAIN_SIZE = 0.75
ratings = shuffle(ratings, random_state=1)
cutoff = int(TRAIN_SIZE * len(ratings))
ratings_train = ratings.iloc[:cutoff]
ratings_test = ratings.iloc[cutoff:]

# %% [markdown]
# - TRAIN과 TEST데이터에 대한 새로운 MF 클래스

# %%
class NEW_MF():
    def __init__(self, ratings, K, alpha, beta, iterations, verbose=True):
        self.R = np.array(ratings)
##### >>>>> (2) user_id, item_id를 R의 index와 매핑하기 위한 dictionary 생성
        item_id_index = []
        index_item_id = []
        for i, one_id in enumerate(ratings):
            item_id_index.append([one_id, i])
            index_item_id.append([i, one_id])
        self.item_id_index = dict(item_id_index)
        self.index_item_id = dict(index_item_id)        
        user_id_index = []
        index_user_id = []
        for i, one_id in enumerate(ratings.T):
            user_id_index.append([one_id, i])
            index_user_id.append([i, one_id])
        self.user_id_index = dict(user_id_index)
        self.index_user_id = dict(index_user_id)
#### <<<<< (2)
        self.num_users, self.num_items = np.shape(self.R)
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations
        self.verbose = verbose

    # train set의 RMSE 계산
    def rmse(self):
        xs, ys = self.R.nonzero()
        self.predictions = []
        self.errors = []
        for x, y in zip(xs, ys):
            prediction = self.get_prediction(x, y)
            self.predictions.append(prediction)
            self.errors.append(self.R[x, y] - prediction)
        self.predictions = np.array(self.predictions)
        self.errors = np.array(self.errors)
        return np.sqrt(np.mean(self.errors**2))

    # 유저(i)와 아이템(j)의 Ratings
    def get_prediction(self, i, j):
        prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j, :].T)
        return prediction

    # P 와 Q matrix를 최적화하기 위한 확률적 경사 하강법
    def sgd(self):
        for i, j, r in self.samples:
            prediction = self.get_prediction(i, j)
            e = (r - prediction)

            self.b_u[i] += self.alpha * (e - self.beta * self.b_u[i])
            self.b_d[j] += self.alpha * (e - self.beta * self.b_d[j])

            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i,:])
            self.Q[j, :] += self.alpha * (e * self.P[i, :] - self.beta * self.Q[j,:])

##### >>>>> (3)
    # Test set을 선정
    def set_test(self, ratings_test):
        test_set = []
        for i in range(len(ratings_test)):      # test 데이터에 있는 각 데이터에 대해서
            x = self.user_id_index[ratings_test.iloc[i, 0]]
            y = self.item_id_index[ratings_test.iloc[i, 1]]
            z = ratings_test.iloc[i, 2]
            test_set.append([x, y, z])
            self.R[x, y] = 0                    # Setting test set ratings to 0
        self.test_set = test_set
        return test_set                         # Return test set

    # Test set의 RMSE 계산
    def test_rmse(self):
        error = 0
        for one_set in self.test_set:
            predicted = self.get_prediction(one_set[0], one_set[1])
            error += pow(one_set[2] - predicted, 2)
        return np.sqrt(error/len(self.test_set))

    # Training 하면서 test set의 정확도를 계산
    def test(self):
        # user-feature 와 item-feature matrix 설정
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))

        # 사용자 평가 경향 설정
        self.b_u = np.zeros(self.num_users)
        self.b_d = np.zeros(self.num_items)
        self.b = np.mean(self.R[self.R.nonzero()])

        # 평점이 있는 요소의 인덱스와 평점을 리스트로 만들어서 samples에 저장
        rows, columns = self.R.nonzero()
        self.samples = [(i, j, self.R[i,j]) for i, j in zip(rows, columns)]

        # 주어진 반복 횟수에 따라 확률적경사하강법 수행
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            self.sgd()
            rmse1 = self.rmse()
            rmse2 = self.test_rmse()
            training_process.append((i+1, rmse1, rmse2))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print("Iteration: %d ; Train RMSE = %.4f ; Test RMSE = %.4f" % (i+1, rmse1, rmse2))
        return training_process

    # 주어진 유저와 영화에 대한 평가 예측
    def get_one_prediction(self, user_id, item_id):
        return self.get_prediction(self.user_id_index[user_id], self.item_id_index[item_id])

    # Full 유저-영화 평가 matrix
    def full_prediction(self):
        return self.b + self.b_u[:,np.newaxis] + self.b_d[np.newaxis,:] + self.P.dot(self.Q.T)

# %% [markdown]
# - 최적의 K값 찾기

# %%
results = []
index = []
for K in range(50, 261, 10):
    print('K =', K)
    R_temp = ratings.pivot(index='user_id', columns='movie_id', values='rating').fillna(0)
    mf = NEW_MF(R_temp, K=K, alpha=0.001, beta=0.02, iterations=300, verbose=True)
    test_set = mf.set_test(ratings_test)
    result = mf.test()
    index.append(K)
    results.append(result)
# Out:
# K = 50
# Iteration: 10 ; Train RMSE = 0.9662 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9415 ; Test RMSE = 0.9645
# Iteration: 30 ; Train RMSE = 0.9305 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9241 ; Test RMSE = 0.9524
# Iteration: 50 ; Train RMSE = 0.9198 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9165 ; Test RMSE = 0.9479
# Iteration: 70 ; Train RMSE = 0.9135 ; Test RMSE = 0.9466
# Iteration: 80 ; Train RMSE = 0.9106 ; Test RMSE = 0.9455
# Iteration: 90 ; Train RMSE = 0.9072 ; Test RMSE = 0.9444
# Iteration: 100 ; Train RMSE = 0.9028 ; Test RMSE = 0.9431
# Iteration: 110 ; Train RMSE = 0.8969 ; Test RMSE = 0.9413
# Iteration: 120 ; Train RMSE = 0.8889 ; Test RMSE = 0.9388
# Iteration: 130 ; Train RMSE = 0.8785 ; Test RMSE = 0.9357
# Iteration: 140 ; Train RMSE = 0.8657 ; Test RMSE = 0.9321
# Iteration: 150 ; Train RMSE = 0.8508 ; Test RMSE = 0.9284
# Iteration: 160 ; Train RMSE = 0.8343 ; Test RMSE = 0.9250
# Iteration: 170 ; Train RMSE = 0.8163 ; Test RMSE = 0.9221
# Iteration: 180 ; Train RMSE = 0.7970 ; Test RMSE = 0.9199
# Iteration: 190 ; Train RMSE = 0.7765 ; Test RMSE = 0.9182
# Iteration: 200 ; Train RMSE = 0.7550 ; Test RMSE = 0.9174
# Iteration: 210 ; Train RMSE = 0.7331 ; Test RMSE = 0.9172
# Iteration: 220 ; Train RMSE = 0.7110 ; Test RMSE = 0.9179
# Iteration: 230 ; Train RMSE = 0.6890 ; Test RMSE = 0.9191
# Iteration: 240 ; Train RMSE = 0.6675 ; Test RMSE = 0.9209
# Iteration: 250 ; Train RMSE = 0.6466 ; Test RMSE = 0.9232
# Iteration: 260 ; Train RMSE = 0.6265 ; Test RMSE = 0.9258
# Iteration: 270 ; Train RMSE = 0.6071 ; Test RMSE = 0.9287
# Iteration: 280 ; Train RMSE = 0.5887 ; Test RMSE = 0.9317
# Iteration: 290 ; Train RMSE = 0.5712 ; Test RMSE = 0.9349
# Iteration: 300 ; Train RMSE = 0.5545 ; Test RMSE = 0.9381
# K = 60
# Iteration: 10 ; Train RMSE = 0.9662 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9415 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9306 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9243 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9200 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9168 ; Test RMSE = 0.9479
# Iteration: 70 ; Train RMSE = 0.9140 ; Test RMSE = 0.9466
# Iteration: 80 ; Train RMSE = 0.9112 ; Test RMSE = 0.9456
# Iteration: 90 ; Train RMSE = 0.9081 ; Test RMSE = 0.9445
# Iteration: 100 ; Train RMSE = 0.9041 ; Test RMSE = 0.9433
# Iteration: 110 ; Train RMSE = 0.8987 ; Test RMSE = 0.9417
# Iteration: 120 ; Train RMSE = 0.8913 ; Test RMSE = 0.9395
# Iteration: 130 ; Train RMSE = 0.8814 ; Test RMSE = 0.9366
# Iteration: 140 ; Train RMSE = 0.8688 ; Test RMSE = 0.9330
# Iteration: 150 ; Train RMSE = 0.8539 ; Test RMSE = 0.9291
# Iteration: 160 ; Train RMSE = 0.8372 ; Test RMSE = 0.9256
# Iteration: 170 ; Train RMSE = 0.8191 ; Test RMSE = 0.9226
# Iteration: 180 ; Train RMSE = 0.7998 ; Test RMSE = 0.9203
# Iteration: 190 ; Train RMSE = 0.7794 ; Test RMSE = 0.9187
# Iteration: 200 ; Train RMSE = 0.7580 ; Test RMSE = 0.9178
# Iteration: 210 ; Train RMSE = 0.7360 ; Test RMSE = 0.9176
# Iteration: 220 ; Train RMSE = 0.7137 ; Test RMSE = 0.9182
# Iteration: 230 ; Train RMSE = 0.6913 ; Test RMSE = 0.9194
# Iteration: 240 ; Train RMSE = 0.6691 ; Test RMSE = 0.9212
# Iteration: 250 ; Train RMSE = 0.6473 ; Test RMSE = 0.9234
# Iteration: 260 ; Train RMSE = 0.6261 ; Test RMSE = 0.9260
# Iteration: 270 ; Train RMSE = 0.6055 ; Test RMSE = 0.9288
# Iteration: 280 ; Train RMSE = 0.5857 ; Test RMSE = 0.9317
# Iteration: 290 ; Train RMSE = 0.5667 ; Test RMSE = 0.9348
# Iteration: 300 ; Train RMSE = 0.5485 ; Test RMSE = 0.9379
# K = 70
# Iteration: 10 ; Train RMSE = 0.9662 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.
; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9418 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9310 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9249 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9208 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9178 ; Test RMSE = 0.9479
# Iteration: 70 ; Train RMSE = 0.9154 ; Test RMSE = 0.9467
# Iteration: 80 ; Train RMSE = 0.9132 ; Test RMSE = 0.9456
# Iteration: 90 ; Train RMSE = 0.9107 ; Test RMSE = 0.9447
# Iteration: 100 ; Train RMSE = 0.9078 ; Test RMSE = 0.9436
# Iteration: 110 ; Train RMSE = 0.9039 ; Test RMSE = 0.9421
# Iteration: 120 ; Train RMSE = 0.8984 ; Test RMSE = 0.9401
# Iteration: 130 ; Train RMSE = 0.8908 ; Test RMSE = 0.9374
# Iteration: 140 ; Train RMSE = 0.8808 ; Test RMSE = 0.9338
# Iteration: 150 ; Train RMSE = 0.8686 ; Test RMSE = 0.9299
# Iteration: 160 ; Train RMSE = 0.8546 ; Test RMSE = 0.9260
# Iteration: 170 ; Train RMSE = 0.8392 ; Test RMSE = 0.9226
# Iteration: 180 ; Train RMSE = 0.8224 ; Test RMSE = 0.9196
# Iteration: 190 ; Train RMSE = 0.8042 ; Test RMSE = 0.9171
# Iteration: 200 ; Train RMSE = 0.7844 ; Test RMSE = 0.9150
# Iteration: 210 ; Train RMSE = 0.7633 ; Test RMSE = 0.9136
# Iteration: 220 ; Train RMSE = 0.7411 ; Test RMSE = 0.9127
# Iteration: 230 ; Train RMSE = 0.7181 ; Test RMSE = 0.9124
# Iteration: 240 ; Train RMSE = 0.6946 ; Test RMSE = 0.9127
# Iteration: 250 ; Train RMSE = 0.6710 ; Test RMSE = 0.9136
# Iteration: 260 ; Train RMSE = 0.6475 ; Test RMSE = 0.9149
# Iteration: 270 ; Train RMSE = 0.6244 ; Test RMSE = 0.9167
# Iteration: 280 ; Train RMSE = 0.6017 ; Test RMSE = 0.9187
# Iteration: 290 ; Train RMSE = 0.5797 ; Test RMSE = 0.9209
# Iteration: 300 ; Train RMSE = 0.5584 ; Test RMSE = 0.9232
# K = 110
# Iteration: 10 ; Train RMSE = 0.9663 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9418 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9311 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9249 ; Test RMSE = 0.9524
# Iteration: 50 ; Train RMSE = 0.9209 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9180 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9156 ; Test RMSE = 0.9467
# Iteration: 80 ; Train RMSE = 0.9135 ; Test RMSE = 0.9457
# Iteration: 90 ; Train RMSE = 0.9112 ; Test RMSE = 0.9448
# Iteration: 100 ; Train RMSE = 0.9085 ; Test RMSE = 0.9438
# Iteration: 110 ; Train RMSE = 0.9049 ; Test RMSE = 0.9426
# Iteration: 120 ; Train RMSE = 0.8998 ; Test RMSE = 0.9408
# Iteration: 130 ; Train RMSE = 0.8928 ; Test RMSE = 0.9383
# Iteration: 140 ; Train RMSE = 0.8836 ; Test RMSE = 0.9351
# Iteration: 150 ; Train RMSE = 0.8721 ; Test RMSE = 0.9314
# Iteration: 180 ; Train RMSE = 0.8438 ; Test RMSE = 0.9233
# Iteration: 190 ; Train RMSE = 0.8280 ; Test RMSE = 0.9203
# Iteration: 200 ; Train RMSE = 0.8107 ; Test RMSE = 0.9176
# Iteration: 210 ; Train RMSE = 0.7916 ; Test RMSE = 0.9153
# Iteration: 220 ; Train RMSE = 0.7711 ; Test RMSE = 0.9134
# Iteration: 230 ; Train RMSE = 0.7491 ; Test RMSE = 0.9121
# Iteration: 240 ; Train RMSE = 0.7261 ; Test RMSE = 0.9114
# Iteration: 250 ; Train RMSE = 0.7024 ; Test RMSE = 0.9113
# Iteration: 260 ; Train RMSE = 0.6783 ; Test RMSE = 0.9118
# Iteration: 270 ; Train RMSE = 0.6540 ; Test RMSE = 0.9127
# Iteration: 280 ; Train RMSE = 0.6300 ; Test RMSE = 0.9140
# Iteration: 290 ; Train RMSE = 0.6063 ; Test RMSE = 0.9157
# Iteration: 300 ; Train RMSE = 0.5831 ; Test RMSE = 0.9175
# K = 180
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9419 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9313 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9252 ; Test RMSE = 0.9524
# Iteration: 50 ; Train RMSE = 0.9213 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9186 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9164 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9146 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9128 ; Test RMSE = 0.9451
# Iteration: 100 ; Train RMSE = 0.9109 ; Test RMSE = 0.9443
# Iteration: 110 ; Train RMSE = 0.9084 ; Test RMSE = 0.9434
# Iteration: 120 ; Train RMSE = 0.9050 ; Test RMSE = 0.9421
# Iteration: 130 ; Train RMSE = 0.9003 ; Test RMSE = 0.9403
# Iteration: 140 ; Train RMSE = 0.8935 ; Test RMSE = 0.9378
# Iteration: 150 ; Train RMSE = 0.8846 ; Test RMSE = 0.9344
# Iteration: 160 ; Train RMSE = 0.8735 ; Test RMSE = 0.9307
# Iteration: 170 ; Train RMSE = 0.8608 ; Test RMSE = 0.9270
# Iteration: 180 ; Train RMSE = 0.8466 ; Test RMSE = 0.9235
# Iteration: 190 ; Train RMSE = 0.8310 ; Test RMSE = 0.9203
# Iteration: 200 ; Train RMSE = 0.8138 ; Test RMSE = 0.9175
# Iteration: 210 ; Train RMSE = 0.7950 ; Test RMSE = 0.9150
# Iteration: 220 ; Train RMSE = 0.7746 ; Test RMSE = 0.9129
# Iteration: 230 ; Train RMSE = 0.7528 ; Test RMSE = 0.9115
# Iteration: 240 ; Train RMSE = 0.7299 ; Test RMSE = 0.9105
# Iteration: 250 ; Train RMSE = 0.7062 ; Test RMSE = 0.9102
# Iteration: 260 ; Train RMSE = 0.6821 ; Test RMSE = 0.9104
# Iteration: 270 ; Train RMSE = 0.6578 ; Test RMSE = 0.9111
# Iteration: 280 ; Train RMSE = 0.6336 ; Test RMSE = 0.9122
# Iteration: 290 ; Train RMSE = 0.6097 ; Test RMSE = 0.9137
# Iteration: 300 ; Train RMSE = 0.5863 ; Test RMSE = 0.9153
# K = 190
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9833
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9313 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9253 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9214 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9186 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9165 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9147 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9130 ; Test RMSE = 0.9451
# Iteration: 100 ; Train RMSE = 0.9111 ; Test RMSE = 0.9444
# Iteration: 110 ; Train RMSE = 0.9088 ; Test RMSE = 0.9435
# Iteration: 120 ; Train RMSE = 0.9056 ; Test RMSE = 0.9423
# Iteration: 130 ; Train RMSE = 0.9011 ; Test RMSE = 0.9406
# Iteration: 140 ; Train RMSE = 0.8947 ; Test RMSE = 0.9381
# Iteration: 150 ; Train RMSE = 0.8861 ; Test RMSE = 0.9349
# Iteration: 160 ; Train RMSE = 0.8754 ; Test RMSE = 0.9312
# Iteration: 170 ; Train RMSE = 0.8629 ; Test RMSE = 0.9274
# Iteration: 180 ; Train RMSE = 0.8490 ; Test RMSE = 0.9239
# Iteration: 190 ; Train RMSE = 0.8336 ; Test RMSE = 0.9207
# Iteration: 200 ; Train RMSE = 0.8165 ; Test RMSE = 0.9177
# Iteration: 210 ; Train RMSE = 0.7978 ; Test RMSE = 0.9151
# Iteration: 220 ; Train RMSE = 0.7775 ; Test RMSE = 0.9129
# Iteration: 230 ; Train RMSE = 0.7558 ; Test RMSE = 0.9113
# Iteration: 240 ; Train RMSE = 0.7330 ; Test RMSE = 0.9103
# Iteration: 250 ; Train RMSE = 0.7095 ; Test RMSE = 0.9098
# Iteration: 260 ; Train RMSE = 0.6854 ; Test RMSE = 0.9100
# Iteration: 270 ; Train RMSE = 0.6612 ; Test RMSE = 0.9106
# Iteration: 280 ; Train RMSE = 0.6370 ; Test RMSE = 0.9116
# Iteration: 290 ; Train RMSE = 0.6131 ; Test RMSE = 0.9129
# Iteration: 300 ; Train RMSE = 0.5896 ; Test RMSE = 0.9146
# K = 200
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9313 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9253 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9214 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9187 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9166 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9148 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9131 ; Test RMSE = 0.9451
# Iteration: 100 ; Train RMSE = 0.9113 ; Test RMSE = 0.9444
# Iteration: 110 ; Train RMSE = 0.9090 ; Test RMSE = 0.9435
# Iteration: 120 ; Train RMSE = 0.9060 ; Test RMSE = 0.9424
# Iteration: 130 ; Train RMSE = 0.9016 ; Test RMSE = 0.9407
# Iteration: 140 ; Train RMSE = 0.8954 ; Test RMSE = 0.9383
# Iteration: 150 ; Train RMSE = 0.8870 ; Test RMSE = 0.9352
# Iteration: 160 ; Train RMSE = 0.8766 ; Test RMSE = 0.9315
# Iteration: 170 ; Train RMSE = 0.8644 ; Test RMSE = 0.9278
# Iteration: 180 ; Train RMSE = 0.8508 ; Test RMSE = 0.9242
# Iteration: 190 ; Train RMSE = 0.8357 ; Test RMSE = 0.9209
# Iteration: 200 ; Train RMSE = 0.8191 ; Test RMSE = 0.9179
# Iteration: 210 ; Train RMSE = 0.8008 ; Test RMSE = 0.9152
# Iteration: 220 ; Train RMSE = 0.7810 ; Test RMSE = 0.9131
# Iteration: 230 ; Train RMSE = 0.7598 ; Test RMSE = 0.9114
# Iteration: 240 ; Train RMSE = 0.7375 ; Test RMSE = 0.9103
# Iteration: 250 ; Train RMSE = 0.7143 ; Test RMSE = 0.9098
# Iteration: 260 ; Train RMSE = 0.6905 ; Test RMSE = 0.9098
# Iteration: 270 ; Train RMSE = 0.6665 ; Test RMSE = 0.9104
# Iteration: 280 ; Train RMSE = 0.6424 ; Test RMSE = 0.9113
# Iteration: 290 ; Train RMSE = 0.6186 ; Test RMSE = 0.9127
# Iteration: 300 ; Train RMSE = 0.5950 ; Test RMSE = 0.9143
# K = 210
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9313 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9253 ; Test RMSE = 0.9524
# Iteration: 50 ; Train RMSE = 0.9214 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9187 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9166 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9148 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9131 ; Test RMSE = 0.9451
# Iteration: 100 ; Train RMSE = 0.9113 ; Test RMSE = 0.9443
# Iteration: 110 ; Train RMSE = 0.9090 ; Test RMSE = 0.9434
# Iteration: 120 ; Train RMSE = 0.9058 ; Test RMSE = 0.9422
# Iteration: 130 ; Train RMSE = 0.9014 ; Test RMSE = 0.9405
# Iteration: 140 ; Train RMSE = 0.8950 ; Test RMSE = 0.9380
# Iteration: 150 ; Train RMSE = 0.8866 ; Test RMSE = 0.9347
# Iteration: 160 ; Train RMSE = 0.8761 ; Test RMSE = 0.9310
# Iteration: 170 ; Train RMSE = 0.8641 ; Test RMSE = 0.9273
# Iteration: 180 ; Train RMSE = 0.8507 ; Test RMSE = 0.9237
# Iteration: 190 ; Train RMSE = 0.8359 ; Test RMSE = 0.9205
# Iteration: 200 ; Train RMSE = 0.8196 ; Test RMSE = 0.9175
# Iteration: 210 ; Train RMSE = 0.8017 ; Test RMSE = 0.9149
# Iteration: 220 ; Train RMSE = 0.7823 ; Test RMSE = 0.9127
# Iteration: 230 ; Train RMSE = 0.7614 ; Test RMSE = 0.9110
# Iteration: 240 ; Train RMSE = 0.7394 ; Test RMSE = 0.9099
# Iteration: 250 ; Train RMSE = 0.7164 ; Test RMSE = 0.9094
# Iteration: 260 ; Train RMSE = 0.6928 ; Test RMSE = 0.9094
# Iteration: 270 ; Train RMSE = 0.6689 ; Test RMSE = 0.9098
# Iteration: 280 ; Train RMSE = 0.6449 ; Test RMSE = 0.9107
# Iteration: 290 ; Train RMSE = 0.6210 ; Test RMSE = 0.9119
# Iteration: 300 ; Train RMSE = 0.5975 ; Test RMSE = 0.9135
# K = 220
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9645
# Iteration: 30 ; Train RMSE = 0.9313 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9253 ; Test RMSE = 0.9524
# Iteration: 50 ; Train RMSE = 0.9214 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9187 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9166 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9149 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9132 ; Test RMSE = 0.9451
# Iteration: 100 ; Train RMSE = 0.9113 ; Test RMSE = 0.9444
# Iteration: 110 ; Train RMSE = 0.9091 ; Test RMSE = 0.9435
# Iteration: 120 ; Train RMSE = 0.9060 ; Test RMSE = 0.9423
# Iteration: 130 ; Train RMSE = 0.9016 ; Test RMSE = 0.9406
# Iteration: 140 ; Train RMSE = 0.8953 ; Test RMSE = 0.9381
# Iteration: 150 ; Train RMSE = 0.8870 ; Test RMSE = 0.9350
# Iteration: 160 ; Train RMSE = 0.8768 ; Test RMSE = 0.9314
# Iteration: 170 ; Train RMSE = 0.8651 ; Test RMSE = 0.9277
# Iteration: 180 ; Train RMSE = 0.8520 ; Test RMSE = 0.9243
# Iteration: 190 ; Train RMSE = 0.8374 ; Test RMSE = 0.9211
# Iteration: 200 ; Train RMSE = 0.8213 ; Test RMSE = 0.9181
# Iteration: 210 ; Train RMSE = 0.8035 ; Test RMSE = 0.9154
# Iteration: 220 ; Train RMSE = 0.7840 ; Test RMSE = 0.9132
# Iteration: 230 ; Train RMSE = 0.7632 ; Test RMSE = 0.9114
# Iteration: 240 ; Train RMSE = 0.7411 ; Test RMSE = 0.9103
# Iteration: 250 ; Train RMSE = 0.7181 ; Test RMSE = 0.9098
# Iteration: 260 ; Train RMSE = 0.6945 ; Test RMSE = 0.9098
# Iteration: 270 ; Train RMSE = 0.6705 ; Test RMSE = 0.9103
# Iteration: 280 ; Train RMSE = 0.6465 ; Test RMSE = 0.9113
# Iteration: 290 ; Train RMSE = 0.6226 ; Test RMSE = 0.9126
# Iteration: 300 ; Train RMSE = 0.5991 ; Test RMSE = 0.9143
# K = 230
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9314 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9253 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9215 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9187 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9167 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9150 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9134 ; Test RMSE = 0.9452
# Iteration: 100 ; Train RMSE = 0.9116 ; Test RMSE = 0.9445
# Iteration: 110 ; Train RMSE = 0.9095 ; Test RMSE = 0.9437
# Iteration: 120 ; Train RMSE = 0.9067 ; Test RMSE = 0.9426
# Iteration: 130 ; Train RMSE = 0.9027 ; Test RMSE = 0.9410
# Iteration: 140 ; Train RMSE = 0.8969 ; Test RMSE = 0.9388
# Iteration: 150 ; Train RMSE = 0.8890 ; Test RMSE = 0.9358
# Iteration: 160 ; Train RMSE = 0.8791 ; Test RMSE = 0.9322
# Iteration: 170 ; Train RMSE = 0.8675 ; Test RMSE = 0.9284
# Iteration: 180 ; Train RMSE = 0.8546 ; Test RMSE = 0.9248
# Iteration: 190 ; Train RMSE = 0.8403 ; Test RMSE = 0.9215
# Iteration: 200 ; Train RMSE = 0.8246 ; Test RMSE = 0.9184
# Iteration: 210 ; Train RMSE = 0.8073 ; Test RMSE = 0.9157
# Iteration: 220 ; Train RMSE = 0.7884 ; Test RMSE = 0.9133
# Iteration: 230 ; Train RMSE = 0.7679 ; Test RMSE = 0.9115
# Iteration: 240 ; Train RMSE = 0.7461 ; Test RMSE = 0.9101
# Iteration: 250 ; Train RMSE = 0.7232 ; Test RMSE = 0.9093
# Iteration: 260 ; Train RMSE = 0.6995 ; Test RMSE = 0.9091
# Iteration: 270 ; Train RMSE = 0.6754 ; Test RMSE = 0.9094
# Iteration: 280 ; Train RMSE = 0.6512 ; Test RMSE = 0.9102
# Iteration: 290 ; Train RMSE = 0.6271 ; Test RMSE = 0.9114
# Iteration: 300 ; Train RMSE = 0.6032 ; Test RMSE = 0.9129
# K = 240
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9645
# Iteration: 30 ; Train RMSE = 0.9314 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9253 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9215 ; Test RMSE = 0.9497
# Iteration: 60 ; Train RMSE = 0.9188 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9167 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9150 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9134 ; Test RMSE = 0.9452
# Iteration: 100 ; Train RMSE = 0.9117 ; Test RMSE = 0.9445
# Iteration: 110 ; Train RMSE = 0.9097 ; Test RMSE = 0.9437
# Iteration: 120 ; Train RMSE = 0.9070 ; Test RMSE = 0.9427
# Iteration: 130 ; Train RMSE = 0.9031 ; Test RMSE = 0.9411
# Iteration: 140 ; Train RMSE = 0.8975 ; Test RMSE = 0.9390
# Iteration: 150 ; Train RMSE = 0.8899 ; Test RMSE = 0.9360
# Iteration: 160 ; Train RMSE = 0.8802 ; Test RMSE = 0.9325
# Iteration: 170 ; Train RMSE = 0.8688 ; Test RMSE = 0.9287
# Iteration: 180 ; Train RMSE = 0.8560 ; Test RMSE = 0.9250
# Iteration: 190 ; Train RMSE = 0.8418 ; Test RMSE = 0.9216
# Iteration: 200 ; Train RMSE = 0.8261 ; Test RMSE = 0.9185
# Iteration: 210 ; Train RMSE = 0.8087 ; Test RMSE = 0.9157
# Iteration: 220 ; Train RMSE = 0.7898 ; Test RMSE = 0.9133
# Iteration: 230 ; Train RMSE = 0.7693 ; Test RMSE = 0.9114
# Iteration: 240 ; Train RMSE = 0.7476 ; Test RMSE = 0.9100
# Iteration: 250 ; Train RMSE = 0.7248 ; Test RMSE = 0.9093
# Iteration: 260 ; Train RMSE = 0.7013 ; Test RMSE = 0.9091
# Iteration: 270 ; Train RMSE = 0.6773 ; Test RMSE = 0.9095
# Iteration: 280 ; Train RMSE = 0.6532 ; Test RMSE = 0.9103
# Iteration: 290 ; Train RMSE = 0.6293 ; Test RMSE = 0.9116
# Iteration: 300 ; Train RMSE = 0.6056 ; Test RMSE = 0.9131
# K = 250
# Iteration: 10 ; Train RMSE = 0.9664 ; Test RMSE = 0.9834
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9644
# Iteration: 30 ; Train RMSE = 0.9314 ; Test RMSE = 0.9566
# Iteration: 40 ; Train RMSE = 0.9254 ; Test RMSE = 0.9523
# Iteration: 50 ; Train RMSE = 0.9215 ; Test RMSE = 0.9498
# Iteration: 60 ; Train RMSE = 0.9188 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9168 ; Test RMSE = 0.9469
# Iteration: 80 ; Train RMSE = 0.9151 ; Test RMSE = 0.9460
# Iteration: 90 ; Train RMSE = 0.9136 ; Test RMSE = 0.9452
# Iteration: 100 ; Train RMSE = 0.9120 ; Test RMSE = 0.9446
# Iteration: 110 ; Train RMSE = 0.9102 ; Test RMSE = 0.9439
# Iteration: 120 ; Train RMSE = 0.9077 ; Test RMSE = 0.9430
# Iteration: 130 ; Train RMSE = 0.9043 ; Test RMSE = 0.9418
# Iteration: 140 ; Train RMSE = 0.8994 ; Test RMSE = 0.9399
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-b941c30ce08d>", line 8, in <module>
#     result = mf.test()
#   File "<ipython-input-12-cc39d683a8c0>", line 97, in test
#     self.sgd()
#   File "<ipython-input-12-cc39d683a8c0>", line 48, in sgd
#     prediction = self.get_prediction(i, j)
#   File "<ipython-input-12-cc39d683a8c0>", line 42, in get_prediction
#     prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j, :].T)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\ProgramData\Anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-13-b941c30ce08d> in <module>
#       7     test_set = mf.set_test(ratings_test)
# ----> 8     result = mf.test()
#       9     index.append(K)
#
# <ipython-input-12-cc39d683a8c0> in test(self)
#      96             np.random.shuffle(self.samples)
# ---> 97             self.sgd()
#      98             rmse1 = self.rmse()
#
# <ipython-input-12-cc39d683a8c0> in sgd(self)
#      47         for i, j, r in self.samples:
# ---> 48             prediction = self.get_prediction(i, j)
#      49             e = (r - prediction)
#
# <ipython-input-12-cc39d683a8c0> in get_prediction(self, i, j)
#      41     def get_prediction(self, i, j):
# ---> 42         prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j, :].T)
#      43         return prediction
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# - 최적의 iterations 값 찾기

# %%
summary = []
for i in range(len(results)):
    RMSE = []
    for result in results[i]:
        RMSE.append(result[2])
    min = np.min(RMSE)
    j = RMSE.index(min)
    summary.append([index[i], j+1, RMSE[j]])

# %% [markdown]
# - 그래프 그리기

# %%
import matplotlib.pyplot as plt
plt.plot(index, [x[2] for x in summary])
plt.ylim(0.89, 0.94)
plt.xlabel('K')
plt.ylabel('RMSE')
plt.show()
